# %% [markdown]
# # Automação do comando INSERT no SQL com Python
#
# ## Processos:
#
# * Passo 1: Copiar do bloco de notas a sintese do comando UPDATE
#
# * Passo 2: Colar no postgres ADMIN
#
# * Passo 3: Fazendo as modificações necessárias
#
# * Passo 4: Tecla "F5"
#
# * Passo 5: Repete

# %%
import pyautogui
import pyperclip
import time
import pandas as pd

# %%
pyautogui.position(x=1067, y=198)
# Out:
# Point(x=1067, y=198)

# %%
# Comando utilizado nenhum comando atropelar o outro no tempo de execução
pyautogui.PAUSE = 1

# Comando para alertar o inicio da automação
pyautogui.alert("Vai começar, aperte OK e não mexa mais!")

pyautogui.click(x=355, y=241)
pyautogui.hotkey('ctrl','a')
pyautogui.hotkey('delete')
pyautogui.click(x=1067, y=198)
pyautogui.hotkey('ctrl','a')
pyautogui.hotkey('ctrl','c')
pyautogui.click(x=355, y=241)
pyautogui.hotkey('ctrl','v')
pyperclip.copy("'Física, Intelectual, Psicossocial'")
pyautogui.click(x=307, y=268)
pyautogui.hotkey('ctrl','v')
pyautogui.click(x=331, y=290)
pyautogui.write("1")
pyautogui.press("f5") #PARA A QUERY INSERIR O DADO
time.sleep(5)

pyautogui.click(x=355, y=241)
pyautogui.hotkey('ctrl','a')
pyautogui.hotkey('delete')
pyautogui.click(x=1067, y=198)
pyautogui.hotkey('ctrl','a')
pyautogui.hotkey('ctrl','c')
pyautogui.click(x=355, y=241)
pyautogui.hotkey('ctrl','v')
pyperclip.copy("'Física, Intelectual, Psicossocial'")
pyautogui.click(x=307, y=268)
pyautogui.hotkey('ctrl','v')
pyautogui.click(x=331, y=290)
pyautogui.write("2")
pyautogui.press("f5") #PARA A QUERY INSERIR O DADO
time.sleep(5)

pyautogui.click(x=355, y=241)
pyautogui.hotkey('ctrl','a')
pyautogui.hotkey('delete')
pyautogui.click(x=1067, y=198)
pyautogui.hotkey('ctrl','a')
pyautogui.hotkey('ctrl','c')
pyautogui.click(x=355, y=241)
pyautogui.hotkey('ctrl','v')
pyperclip.copy("'Física, Intelectual, Psicossocial'")
pyautogui.click(x=307, y=268)
pyautogui.hotkey('ctrl','v')
pyautogui.click(x=331, y=290)
pyautogui.write("3")
pyautogui.press("f5") #PARA A QUERY INSERIR O DADO
time.sleep(5)

pyautogui.click(x=355, y=241)
pyautogui.hotkey('ctrl','a')
pyautogui.hotkey('delete')
pyautogui.click(x=1067, y=198)
pyautogui.hotkey('ctrl','a')
pyautogui.hotkey('ctrl','c')
pyautogui.click(x=355, y=241)
pyautogui.hotkey('ctrl','v')
pyperclip.copy("'Física, Intelectual, Psicossocial'")
pyautogui.click(x=307, y=268)
pyautogui.hotkey('ctrl','v')
pyautogui.click(x=331, y=290)
pyautogui.write("4")
pyautogui.press("f5") #PARA A QUERY INSERIR O DADO
time.sleep(5)

pyautogui.click(x=355, y=241)
pyautogui.hotkey('ctrl','a')
pyautogui.hotkey('delete')
pyautogui.click(x=1067, y=198)
pyautogui.hotkey('ctrl','a')
pyautogui.hotkey('ctrl','c')
pyautogui.click(x=355, y=241)
pyautogui.hotkey('ctrl','v')
pyperclip.copy("'Física, Intelectual, Psicossocial'")
pyautogui.click(x=307, y=268)
pyautogui.hotkey('ctrl','v')
pyautogui.click(x=331, y=290)
pyautogui.write("5")
pyautogui.press("f5") #PARA A QUERY INSERIR O DADO
time.sleep(5)

pyautogui.click(x=355, y=241)
pyautogui.hotkey('ctrl','a')
pyautogui.hotkey('delete')
pyautogui.click(x=1067, y=198)
pyautogui.hotkey('ctrl','a')
pyautogui.hotkey('ctrl','c')
pyautogui.click(x=355, y=241)
pyautogui.hotkey('ctrl','v')
pyperclip.copy("'Física, Intelectual, Psicossocial'")
pyautogui.click(x=307, y=268)
pyautogui.hotkey('ctrl','v')
pyautogui.click(x=331, y=290)
pyautogui.write("6")
pyautogui.press("f5") #PARA A QUERY INSERIR O DADO
time.sleep(5)

pyautogui.click(x=355, y=241)
pyautogui.hotkey('ctrl','a')
pyautogui.hotkey('delete')
pyautogui.click(x=1067, y=198)
pyautogui.hotkey('ctrl','a')
pyautogui.hotkey('ctrl','c')
pyautogui.click(x=355, y=241)
pyautogui.hotkey('ctrl','v')
pyperclip.copy("'Física, Intelectual, Psicossocial'")
pyautogui.click(x=307, y=268)
pyautogui.hotkey('ctrl','v')
pyautogui.click(x=331, y=290)
pyautogui.write("7")
pyautogui.press("f5") #PARA A QUERY INSERIR O DADO
time.sleep(5)

pyautogui.click(x=355, y=241)
pyautogui.hotkey('ctrl','a')
pyautogui.hotkey('delete')
pyautogui.click(x=1067, y=198)
pyautogui.hotkey('ctrl','a')
pyautogui.hotkey('ctrl','c')
pyautogui.click(x=355, y=241)
pyautogui.hotkey('ctrl','v')
pyperclip.copy("'Física, Visual, Intelectual'")
pyautogui.click(x=307, y=268)
pyautogui.hotkey('ctrl','v')
pyautogui.click(x=331, y=290)
pyautogui.write("8")
pyautogui.press("f5") #PARA A QUERY INSERIR O DADO
time.sleep(5)

pyautogui.click(x=355, y=241)
pyautogui.hotkey('ctrl','a')
pyautogui.hotkey('delete')
pyautogui.click(x=1067, y=198)
pyautogui.hotkey('ctrl','a')
pyautogui.hotkey('ctrl','c')
pyautogui.click(x=355, y=241)
pyautogui.hotkey('ctrl','v')
pyperclip.copy("'Intelectual, Psicossocial'")
pyautogui.click(x=307, y=268)
pyautogui.hotkey('ctrl','v')
pyautogui.click(x=331, y=290)
pyautogui.write("9")
pyautogui.press("f5") #PARA A QUERY INSERIR O DADO
time.sleep(5)

pyautogui.click(x=355, y=241)
pyautogui.hotkey('ctrl','a')
pyautogui.hotkey('delete')
pyautogui.click(x=1067, y=198)
pyautogui.hotkey('ctrl','a')
pyautogui.hotkey('ctrl','c')
pyautogui.click(x=355, y=241)
pyautogui.hotkey('ctrl','v')
pyperclip.copy("'Física, Visual, Auditiva'")
pyautogui.click(x=307, y=268)
pyautogui.hotkey('ctrl','v')
pyautogui.click(x=331, y=290)
pyautogui.write("10")
pyautogui.press("f5") #PARA A QUERY INSERIR O DADO
time.sleep(5)

pyautogui.click(x=355, y=241)
pyautogui.hotkey('ctrl','a')
pyautogui.hotkey('delete')
pyautogui.click(x=1067, y=198)
pyautogui.hotkey('ctrl','a')
pyautogui.hotkey('ctrl','c')
pyautogui.click(x=355, y=241)
pyautogui.hotkey('ctrl','v')
pyperclip.copy("'Física'")
pyautogui.click(x=307, y=268)
pyautogui.hotkey('ctrl','v')
pyautogui.click(x=331, y=290)
pyautogui.write("11")
pyautogui.press("f5") #PARA A QUERY INSERIR O DADO
time.sleep(5)

pyautogui.click(x=355, y=241)
pyautogui.hotkey('ctrl','a')
pyautogui.hotkey('delete')
pyautogui.click(x=1067, y=198)
pyautogui.hotkey('ctrl','a')
pyautogui.hotkey('ctrl','c')
pyautogui.click(x=355, y=241)
pyautogui.hotkey('ctrl','v')
pyperclip.copy("'Física'")
pyautogui.click(x=307, y=268)
pyautogui.hotkey('ctrl','v')
pyautogui.click(x=331, y=290)
pyautogui.write("12")
pyautogui.press("f5") #PARA A QUERY INSERIR O DADO
time.sleep(5)

pyautogui.click(x=355, y=241)
pyautogui.hotkey('ctrl','a')
pyautogui.hotkey('delete')
pyautogui.click(x=1067, y=198)
pyautogui.hotkey('ctrl','a')
pyautogui.hotkey('ctrl','c')
pyautogui.click(x=355, y=241)
pyautogui.hotkey('ctrl','v')
pyperclip.copy("'Física'")
pyautogui.click(x=307, y=268)
pyautogui.hotkey('ctrl','v')
pyautogui.click(x=331, y=290)
pyautogui.write("13")
pyautogui.press("f5") #PARA A QUERY INSERIR O DADO
time.sleep(5)

pyautogui.click(x=355, y=241)
pyautogui.hotkey('ctrl','a')
pyautogui.hotkey('delete')
pyautogui.click(x=1067, y=198)
pyautogui.hotkey('ctrl','a')
pyautogui.hotkey('ctrl','c')
pyautogui.click(x=355, y=241)
pyautogui.hotkey('ctrl','v')
pyperclip.copy("'Visual'")
pyautogui.click(x=307, y=268)
pyautogui.hotkey('ctrl','v')
pyautogui.click(x=331, y=290)
pyautogui.write("14")
pyautogui.press("f5") #PARA A QUERY INSERIR O DADO
time.sleep(5)

pyautogui.click(x=355, y=241)
pyautogui.hotkey('ctrl','a')
pyautogui.hotkey('delete')
pyautogui.click(x=1067, y=198)
pyautogui.hotkey('ctrl','a')
pyautogui.hotkey('ctrl','c')
pyautogui.click(x=355, y=241)
pyautogui.hotkey('ctrl','v')
pyperclip.copy("'Auditiva'")
pyautogui.click(x=307, y=268)
pyautogui.hotkey('ctrl','v')
pyautogui.click(x=331, y=290)
pyautogui.write("15")
pyautogui.press("f5") #PARA A QUERY INSERIR O DADO
time.sleep(5)

pyautogui.click(x=355, y=241)
pyautogui.hotkey('ctrl','a')
pyautogui.hotkey('delete')
pyautogui.click(x=1067, y=198)
pyautogui.hotkey('ctrl','a')
pyautogui.hotkey('ctrl','c')
pyautogui.click(x=355, y=241)
pyautogui.hotkey('ctrl','v')
pyperclip.copy("'Visual'")
pyautogui.click(x=307, y=268)
pyautogui.hotkey('ctrl','v')
pyautogui.click(x=331, y=290)
pyautogui.write("16")
pyautogui.press("f5") #PARA A QUERY INSERIR O DADO
time.sleep(5)

pyautogui.click(x=355, y=241)
pyautogui.hotkey('ctrl','a')
pyautogui.hotkey('delete')
pyautogui.click(x=1067, y=198)
pyautogui.hotkey('ctrl','a')
pyautogui.hotkey('ctrl','c')
pyautogui.click(x=355, y=241)
pyautogui.hotkey('ctrl','v')
pyperclip.copy("'Física'")
pyautogui.click(x=307, y=268)
pyautogui.hotkey('ctrl','v')
pyautogui.click(x=331, y=290)
pyautogui.write("17")
pyautogui.press("f5") #PARA A QUERY INSERIR O DADO
time.sleep(5)

pyautogui.click(x=355, y=241)
pyautogui.hotkey('ctrl','a')
pyautogui.hotkey('delete')
pyautogui.click(x=1067, y=198)
pyautogui.hotkey('ctrl','a')
pyautogui.hotkey('ctrl','c')
pyautogui.click(x=355, y=241)
pyautogui.hotkey('ctrl','v')
pyperclip.copy("'Visual'")
pyautogui.click(x=307, y=268)
pyautogui.hotkey('ctrl','v')
pyautogui.click(x=331, y=290)
pyautogui.write("18")
pyautogui.press("f5") #PARA A QUERY INSERIR O DADO
time.sleep(5)

pyautogui.click(x=355, y=241)
pyautogui.hotkey('ctrl','a')
pyautogui.hotkey('delete')
pyautogui.click(x=1067, y=198)
pyautogui.hotkey('ctrl','a')
pyautogui.hotkey('ctrl','c')
pyautogui.click(x=355, y=241)
pyautogui.hotkey('ctrl','v')
pyperclip.copy("'Visual'")
pyautogui.click(x=307, y=268)
pyautogui.hotkey('ctrl','v')
pyautogui.click(x=331, y=290)
pyautogui.write("19")
pyautogui.press("f5") #PARA A QUERY INSERIR O DADO
time.sleep(5)

pyautogui.click(x=355, y=241)
pyautogui.hotkey('ctrl','a')
pyautogui.hotkey('delete')
pyautogui.click(x=1067, y=198)
pyautogui.hotkey('ctrl','a')
pyautogui.hotkey('ctrl','c')
pyautogui.click(x=355, y=241)
pyautogui.hotkey('ctrl','v')
pyperclip.copy("'Física, Psicossocial'")
pyautogui.click(x=307, y=268)
pyautogui.hotkey('ctrl','v')
pyautogui.click(x=331, y=290)
pyautogui.write("20")
pyautogui.press("f5") #PARA A QUERY INSERIR O DADO

pyautogui.alert("Finalizado!")
# Out:
# 'OK'

# %% [markdown]
# UPDATE
# 	ACESSIBILIDADE
# SET
# 	tipo_deficiencia = 'Física, Intelectual'
# WHERE id_acessibilidade = 3;
#
# UPDATE
# 	ACESSIBILIDADE
# SET
# 	tipo_deficiencia = 'Visual, Auditiva, Física'
# WHERE id_acessibilidade = 4;
#
# UPDATE
# 	ACESSIBILIDADE
# SET
# 	tipo_deficiencia = 'Auditiva, Visual'
# WHERE id_acessibilidade = 5;
#
# UPDATE
# 	ACESSIBILIDADE
# SET
# 	tipo_deficiencia = 'Física, Intelectual, Múltipla'
# WHERE id_acessibilidade = 6;
#
# UPDATE
# 	ACESSIBILIDADE
# SET
# 	tipo_deficiencia = 'Física, Intelectual, Psicossocial'
# WHERE id_acessibilidade = 7;
#
# UPDATE
# 	ACESSIBILIDADE
# SET
# 	tipo_deficiencia = 'Física, Visual, Intelectual'
# WHERE id_acessibilidade = 8;
#
# UPDATE
# 	ACESSIBILIDADE
# SET
# 	tipo_deficiencia = 'Intelectual, Psicossocial'
# WHERE id_acessibilidade = 9;
#
# UPDATE
# 	ACESSIBILIDADE
# SET
# 	tipo_deficiencia = 'Física, Visual, Auditiva'
# WHERE id_acessibilidade = 10;
#
# UPDATE
# 	ACESSIBILIDADE
# SET
# 	tipo_deficiencia = 'Física'
# WHERE id_acessibilidade = 11;
#
# UPDATE
# 	ACESSIBILIDADE
# SET
# 	tipo_deficiencia = 'Física'
# WHERE id_acessibilidade = 12;
#
# UPDATE
# 	ACESSIBILIDADE
# SET
# 	tipo_deficiencia = 'Física'
# WHERE id_acessibilidade = 13;
#
# UPDATE
# 	ACESSIBILIDADE
# SET
# 	tipo_deficiencia = 'Visual'
# WHERE id_acessibilidade = 14;
#
# UPDATE
# 	ACESSIBILIDADE
# SET
# 	tipo_deficiencia = 'Auditiva'
# WHERE id_acessibilidade = 15;
#
# UPDATE
# 	ACESSIBILIDADE
# SET
# 	tipo_deficiencia = 'Visual'
# WHERE id_acessibilidade = 16;
#
# UPDATE
# 	ACESSIBILIDADE
# SET
# 	tipo_deficiencia = 'Física'
# WHERE id_acessibilidade = 17;
#
# UPDATE
# 	ACESSIBILIDADE
# SET
# 	tipo_deficiencia = 'Visual'
# WHERE id_acessibilidade = 18;
#
# UPDATE
# 	ACESSIBILIDADE
# SET
# 	tipo_deficiencia = 'Visual'
# WHERE id_acessibilidade = 19;
#
# UPDATE
# 	ACESSIBILIDADE
# SET
# 	tipo_deficiencia = 'Física, Psicossocial'
# WHERE id_acessibilidade = 20;
